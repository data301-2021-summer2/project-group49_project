# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import matplotlib.pyplot as plt

# %%
 # the loaded data file
    
data = pd.read_csv('heart_attack_processed.csv')    
data.head()

#heart_file = pd.DataFrame({'': rng.rand(#whatever)})
# can specify what columns you want 
# heart_file.dropna().describe()


#heart_file = pd.read_csv('heart_attack_processed.csv')
#df = pd.DataFrame(data.data,
                  #columns = data.feature_names)

#df = pd.DataFrame(data.data,
                 # columns = data.feature_names)

#df
# Used information from source below to convert excel file to csv file
#https://datatofish.com/excel-to-csv-python/
# Out:
#    Unnamed: 0  age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  \
# 0           0   63    1   3     145   233    1        0       150     0
# 1           1   37    1   2     130   250    0        1       187     0
# 2           2   41    0   1     130   204    0        0       172     0
# 3           3   56    1   1     120   236    0        1       178     0
# 4           4   57    0   0     120   354    0        1       163     1
#
#    oldpeak  slp  caa  thall  output
# 0      2.3    0    0      1       1
# 1      3.5    0    0      2       1
# 2      1.4    2    0      2       1
# 3      0.8    2    0      2       1
# 4      0.6    2    0      2       1

# %%
data.keys()
# Out:
# Index(['Unnamed: 0', 'age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg',
#        'thalachh', 'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Unnamed: 0      int64
# age             int64
# sex             int64
# cp              int64
# trtbps          int64
# chol            int64
# fbs             int64
# restecg         int64
# thalachh        int64
# exng            int64
# oldpeak       float64
# slp             int64
# caa             int64
# thall           int64
# output          int64
# dtype: object

# %%
columns = ('0','age','sex','cp','trtbps','chol','restecg','thalachh','exng','oldpeak','slp','caa','thall','ouput')

# %%
# Method chain 1 (Load data, clean data and deal with missing data)

df = (data.rename(columns = {'age':'Age', 'sex':'Sex of Patient',
                     'cp':'Chest Pain','trtbps':'Resting bp(mmHg)','chol':'Cholesterol',
                     'restecg':'Resting ECG','thalachh':'Max Heart Rate'})
        .dropna(axis ='columns'))  

df
# Out:
#      Unnamed: 0  Age  Sex of Patient  Chest Pain  Resting bp(mmHg)  \
# 0             0   63               1           3               145
# 1             1   37               1           2               130
# 2             2   41               0           1               130
# 3             3   56               1           1               120
# 4             4   57               0           0               120
# ..          ...  ...             ...         ...               ...
# 298         298   57               0           0               140
# 299         299   45               1           3               110
# 300         300   68               1           0               144
# 301         301   57               1           0               130
# 302         302   57               0           1               130
#
#      Cholesterol  fbs  Resting ECG  Max Heart Rate  exng  oldpeak  slp  caa  \
# 0            233    1            0             150     0      2.3    0    0
# 1            250    0            1             187     0      3.5    0    0
# 2            204    0            0             172     0      1.4    2    0
# 3            236    0            1             178     0      0.8    2    0
# 4            354    0            1             163     1      0.6    2    0
# ..           ...  ...          ...             ...   ...      ...  ...  ...
# 298          241    0            1             123     1      0.2    1    0
# 299          264    0            1             132     0      1.2    1    0
# 300          193    1            1             141     0      3.4    1    2
# 301          131    0            1             115     1      1.2    1    1
# 302          236    0            0             174     0      0.0    1    1
#
#      thall  output
# 0        1       1
# 1        2       1
# 2        2       1
# 3        2       1
# 4        2       1
# ..     ...     ...
# 298      3       0
# 299      3       0
# 300      3       0
# 301      3       0
# 302      2       0
#
# [303 rows x 15 columns]

# %%
#Cleaning data and removing any unused columns

del df['exng']

# %%
del df['slp']

# %%
del df['thall']

# %%
del df['caa']

# %%
del df['oldpeak']

# %%
df.head()
# Out:
#    Unnamed: 0  Age  Sex of Patient  Chest Pain  Resting bp(mmHg)  Cholesterol  \
# 0           0   63               1           3               145          233
# 1           1   37               1           2               130          250
# 2           2   41               0           1               130          204
# 3           3   56               1           1               120          236
# 4           4   57               0           0               120          354
#
#    fbs  Resting ECG  Max Heart Rate  output
# 0    1            0             150       1
# 1    0            1             187       1
# 2    0            0             172       1
# 3    0            1             178       1
# 4    0            1             163       1

# %%
 ##Task 2
    # Method Chaining

# %%
# to find the average of rows/ columns 

df.mean(axis ='columns')
